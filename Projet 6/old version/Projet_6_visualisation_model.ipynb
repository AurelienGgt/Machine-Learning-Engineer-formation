# %%
pip install wefe
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 7.9 MB 31.9 MB/s
# ...

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Model :

# %% [markdown]
# ## From Scratch :

# %% [markdown]
# ### VGG16 + Data Augmentation :

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
vgg16_DA_scratch = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Projet_6/training_vgg16_DA_scratch.log', sep=',', engine='python')

# %%
vgg16_DA_scratch
# Out:
#     epoch  accuracy      loss  val_accuracy  val_loss
# 0       0  0.112479  2.361867      0.114350  2.304843
# 1       1  0.112479  2.354034      0.114350  2.304631
# 2       2  0.112479  2.346736      0.114350  2.304473
# 3       3  0.112479  2.340929      0.114350  2.304358
# 4       4  0.112479  2.336057      0.114350  2.304257
# 5       5  0.112479  2.331738      0.114350  2.304169
# 6       6  0.111919  2.328223      0.114350  2.304092
# 7       7  0.112479  2.325765      0.114350  2.304020
# 8       8  0.112479  2.322001      0.114350  2.303959
# 9       9  0.113039  2.319455      0.114350  2.303903
# 10     10  0.113039  2.318105      0.114350  2.303850
# 11     11  0.111919  2.316409      0.114350  2.303800
# 12     12  0.111360  2.313454      0.114350  2.303756
# 13     13  0.112479  2.312430      0.114350  2.303716
# 14     14  0.111919  2.311095      0.114350  2.303681
# 15     15  0.112479  2.309901      0.116592  2.303652
# ...

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### AlexNet

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
scratch_AlexNet = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Projet_6/scratch_AlexNet.log', sep=',', engine='python')

# %%
scratch_AlexNet
# Out:
#     epoch      loss  sparse_categorical_accuracy  val_loss  \
# 0       0  1.933280                     0.361500  2.572741
# 1       1  1.876887                     0.371572  2.185130
# 2       2  1.814459                     0.381086  1.986337
# 3       3  1.662149                     0.435926  1.956255
# 4       4  1.594644                     0.450476  3.152003
# 5       5  1.508107                     0.491326  1.877693
# 6       6  1.422087                     0.511472  1.936767
# 7       7  1.246571                     0.574706  1.961598
# 8       8  1.234367                     0.566312  2.294388
# 9       9  1.139814                     0.611080  2.177557
# 10     10  0.965535                     0.675434  1.912175
#
#     val_sparse_categorical_accuracy
# 0                          0.217489
# 1                          0.280269
# 2                          0.271300
# 3                          0.298206
# 4                          0.242152
# ...

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### AlexNet + GreyScale :

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
scratch_AlexNet_grey = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Projet_6/scratch_AlexNet_grey.log', sep=',', engine='python')

# %%
scratch_AlexNet_grey
# Out:
#     epoch      loss  sparse_categorical_accuracy  val_loss  \
# 0       0  4.214293                     0.171237  2.493808
# 1       1  2.406453                     0.205372  2.077080
# 2       2  2.227090                     0.240067  2.001240
# 3       3  2.153831                     0.248461  1.991134
# 4       4  2.052958                     0.279799  2.093374
# 5       5  1.980605                     0.301063  2.090170
# 6       6  1.918233                     0.322328  2.056335
# 7       7  1.802003                     0.350308  1.909307
# 8       8  1.725976                     0.377168  1.908258
# 9       9  1.735691                     0.388920  2.476578
# 10     10  1.661628                     0.422496  2.042484
# 11     11  1.581605                     0.443201  1.967831
# 12     12  1.546862                     0.462227  1.899105
# 13     13  1.423461                     0.486849  2.188597
# 14     14  1.321392                     0.536094  1.975129
# ...

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Transfert Learning with 10 breeds :

# %% [markdown]
# ### RestNet 50 :

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
restnet50 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Projet_6/training_restnet50.log', sep=',', engine='python')

# %%
restnet50
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.651931  1.319078      0.836323  0.425361
# 1      1  0.835478  0.464019      0.856502  0.397788
# 2      2  0.881925  0.358109      0.874439  0.336215
# 3      3  0.900951  0.291820      0.885650  0.326993
# 4      4  0.918858  0.223734      0.863229  0.418423
# 5      5  0.927252  0.216824      0.854260  0.419354
# 6      6  0.931729  0.205464      0.878924  0.355162
# 7      7  0.936206  0.180698      0.849776  0.481989
# 8      8  0.946838  0.144399      0.860987  0.450724

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### EfficientNet :

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
efficient_net_model = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Projet_6/efficient_net_model.log', sep=',', engine='python')

# %%
efficient_net_model
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.897034  0.307667      0.948430  0.122179
# 1      1  0.956911  0.123854      0.961883  0.120557
# 2      2  0.969222  0.085894      0.950673  0.162493
# 3      3  0.958030  0.108171      0.959641  0.146311
# 4      4  0.974259  0.074072      0.934978  0.207863
# 5      5  0.974818  0.072902      0.934978  0.252236
# 6      6  0.980414  0.052557      0.961883  0.134165

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Xception :

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
xcept_model = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Projet_6/xcept_model.log', sep=',', engine='python')

# %%
xcept_model
# Out:
#     epoch  accuracy      loss  val_accuracy  val_loss
# 0       0  0.134863  4.619046      0.179372  2.241456
# 1       1  0.162283  2.283736      0.177130  2.254277
# 2       2  0.160604  2.287922      0.156951  2.261556
# 3       3  0.153889  2.263085      0.183857  2.256709
# 4       4  0.170118  2.236116      0.192825  2.224884
# 5       5  0.193621  2.215805      0.208520  2.217429
# 6       6  0.189703  2.210195      0.217489  2.214252
# 7       7  0.198097  2.181166      0.215247  2.193281
# 8       8  0.176833  2.203145      0.206278  2.192152
# 9       9  0.215445  2.150222      0.206278  2.194642
# 10     10  0.216564  2.136475      0.217489  2.184517
# 11     11  0.213206  2.140014      0.213004  2.156499
# 12     12  0.219362  2.119359      0.230942  2.138174
# 13     13  0.218243  2.123830      0.190583  2.200763
# 14     14  0.233912  2.093385      0.235426  2.163794
# 15     15  0.223839  2.093401      0.221973  2.139038
# ...

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Inception v3 :

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
InceptionV3_model = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Projet_6/InceptionV3_model.log', sep=',', engine='python')

# %%
InceptionV3_model
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.098489  6.162754       0.11435  2.301783
# 1      1  0.112479  2.307181       0.11435  2.301832
# 2      2  0.113039  2.301091       0.11435  2.301708
# 3      3  0.113598  2.302271       0.11435  2.301674
# 4      4  0.112479  2.301552       0.11435  2.301560
# 5      5  0.112479  2.301536       0.11435  2.301728
# 6      6  0.112479  2.301430       0.11435  2.302244
# 7      7  0.112479  2.301330       0.11435  2.302408
# 8      8  0.112479  2.301290       0.11435  2.302439
# 9      9  0.112479  2.301257       0.11435  2.302475

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Transfert Learning with all breeds :

# %% [markdown]
# ### EfficientNet :

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
efficient_net_model_full = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Projet_6/efficient_net_model_full.log', sep=',', engine='python')

# %%
efficient_net_model_full
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.696672  1.083499      0.804422  0.618423
# 1      1  0.801628  0.656084      0.818999  0.596648
# 2      2  0.831450  0.547351      0.825073  0.619828
# 3      3  0.850826  0.490515      0.824830  0.620012
# 4      4  0.863156  0.447623      0.832119  0.634692

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
